# %%
from src.filter_data import filter_data_func
from src.train_model import multiple_poisson, multiple_XGBoost
from src.test_models import test_models

# %%
df = filter_data_func(min_date="1920-06-10", max_date="2026-06-10")

# %%
df
# Out:
#             date    home_team                 away_team  home_score  \
# 0     1920-06-13       Norway                   Denmark         1.0
# 1     1920-06-27       Norway                    Sweden         0.0
# 2     1920-06-27  Switzerland                   Germany         4.0
# 3     1920-07-18      Uruguay                 Argentina         2.0
# 4     1920-07-25    Argentina                   Uruguay         1.0
# ...          ...          ...                       ...         ...
# 48784 2026-06-09      Armenia                   Moldova         1.0
# 48785 2026-06-09    Argentina                   Iceland         3.0
# 48786 2026-06-09       Angola  Central African Republic         3.0
# 48787 2026-06-09     Ethiopia                    Malawi         1.0
# 48788 2026-06-09         Iraq                 Venezuela         0.0
#
#        away_score                  tournament          city        country  \
# ...

# %%
test_scores = test_models(df)

# %%
test_scores
# Out:
#    glm_home_score  xgb_home_score  glm_away_score  xgb_away_score
# 0        1.258666        1.404152        1.336707        1.345869

# %%
models_xgboost = multiple_XGBoost(df)

# %%
models = multiple_poisson(df)

# %%
print(models[0].summary())
# Out:
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:             home_score   No. Observations:                49401
# Model:                            GLM   Df Residuals:                    48557
# Model Family:                 Poisson   Df Model:                          843
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -78489.
# Date:                Wed, 17 Jun 2026   Deviance:                       60198.
# Time:                        19:09:57   Pearson chi2:                 5.52e+04
# No. Iterations:                    23   Pseudo R-squ. (CS):             0.3834
# Covariance Type:            nonrobust
# ...
#                                                                           coef    std err          z      P>|z|      [0.025      0.975]
# ...
